# %%
from openai import OpenAI
import os
from dotenv import load_dotenv
load_dotenv() 

api_key = os.getenv("API_KEY") 
data_folder = os.getenv("DATA_FOLDER")
base_url = "https://chat-ai.academiccloud.de/v1"
model = "meta-llama-3.1-70b-instruct"  # Choose any available model
temperature = 0.01

# Start OpenAI client
client = OpenAI(
    api_key=api_key,
    base_url=base_url
    )

def process_prompt(prompt):
    # Get response
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "system", "content": "SYSTEM MESSAGE"},
            {"role": "user", "content": prompt}
        ],
        model=model,
        temperature=temperature
    )

    return chat_completion.choices[0].message.content

print(process_prompt("Hello!"))
# Out:
# Hello. How can I help you today?

# %% [markdown]
# Get the prompt template and the pre-processed articles.

# %%
#open the prompt
version = 3
prompt_path = f"../prompts/prompt_v{version}.txt"
with open(prompt_path, "r", encoding="utf-8") as f:
    prompt = f.read()

print(prompt)
# Out:
# We define a claim as an elementary information unit in a sentence, which no longer
# needs to be further split. Furthermore, core claims are ones that best describe
# the core ideas of an article.
#
#
#
# For example, given the following article:
# INPUT:
# {'headline': 'Three Russia Hoax Bombshells Hidden In IG Report On DOJ Surveillance Of Congress', 1: 'By: Mollie Hemingway\nDecember 17, 2024\n9 min read\nSen. Adam Schiff\nImage Credit\nSen. Adam Schiff/YouTube\n\nThese revelations show why the DOJ needs massive reform in the next administration.', 2: 'Author Mollie Hemingway profile\nMollie Hemingway\nVisit on Twitter\n@mzhemingway\nMore Articles\nShare\n\n    Share Article on Facebook\n    Share Article on Twitter\n\nShare Article on Truth Social\n\n    Share Article via Email\n\nLast week the Department of Justice’s inspector general released a report on some of the DOJ’s tracking of communications from media and congressional figures as part of its purported investigation into who was leaking classified information against President Donald Trump in 2017.', 3: 'Three significant bombshells about the Russia collusion hoax were hidden inside the dense and dry 100-page report.', 4: 'For context, when Trump won the 2016 presidential election, anonymous Democrat operatives in the federal government and Congress began leaking like sieves as part of a coordinated effort to paint Trump as a mastermind spy who had worked with Russian President Vladimir Putin for decades in order to steal the election.', 5: 'Two Washington Post stories, a New York Times story, and a CNN story were all found to have included classified information.', 6: 'None of the four stories are specified in the report, but they all appeared in the first half of President Trump’s first year in office.', 7: 'The first Washington Post story is likely the April 2017 story by Ellen Nakashima, Devlin Barrett, and Adam Entous revealing that DOJ had gotten a Foreign Intelligence Surveillance Act (FISA) warrant to spy on Carter Page, a Trump affiliate.', 8: 'The true story of that warrant would end up revealing the corruption of the DOJ, including how it falsified evidence in its application and relied on the laughable Steele dossier as the basis.', 9: 'But at the time of its publication, the FISA story suggested that an honorable DOJ had serious reason to suspect the Trump campaign of colluding with Russia to steal the election.', 10: 'As outlandish and unhinged as the conspiracy theory was, it was fueled with daily drops of classified and deceptively packaged information designed to make it appear legitimate.', 11: 'The corporate media dutifully regurgitated, published, and aired the leaks as part of their campaign against the Republican president.', 12: 'Nakashima, Barrett, and Entous were awarded a Pulitzer Prize for their perpetuation of the Russia collusion hoax in this and other stories.', 13: 'The leaks, which threatened national security and were intended to get Trump removed from office, threw the White House into chaos.', 14: 'For years, polling has indicated that most Democrats continued to cling to the conspiracy theory as an explanation for Trump’s first presidential victory.', 15: 'The leakers have never been brought to justice.', 16: 'Bombshell #1: A Democrat Whistleblower Identified Schiff, Swalwell As Leakers\n\nOne of the more surprising claims in the report was that a Democrat staffer on one of the congressional committees “voluntarily told the FBI” almost immediately after the investigation began in 2017 that he suspected two members of Congress and a number of Democrat staffers of being involved in the leaking of the classified information, leading to further investigation of those identified.', 17: 'While the report doesn’t identify the whistleblower, his committee, or name the members of Congress, a 2021 New York Times story already identified then-Rep. Adam Schiff and Rep. Eric Swalwell, both of California, as the two congressmen on the House Permanent Select Committee on Intelligence (HPSCI) who were under investigation.', 18: 'The DOJ report further notes that only these two members of Congress were investigated.', 19: 'Schiff was the top Democrat on HPSCI at the time its Republican chair Devin  ...
# OUTPUT:
# {   "article_title": "Three Russia Hoax Bombshells Hidden In IG Report On DOJ Surveillance Of Congress",
#     "url": "https://thefederalist.com/2024/12/17/three-russia-hoax-bombshells-hidden-in-ig-report-on-doj-surveillance-of-congress/",
#     "article_length": 64,
#     "claims": [
#     {
#         "claim": "The Department of Justice's inspector general released a report on the DOJ's tracking of communications from media and congressional figures.",
#         "headline": 0,
#         "position": 2
#     },
#     {
#         "claim": "The report revealed that a Democrat staffer on a congressional committee identified two members of Congress and several Democrat staffers as potential leakers of classified information.",
#         "headline": 0,
#         "position": 15
#     },
#     {
#         "claim": "Rep. Adam Schiff and Rep. Eric Swalwell were under investigation for leaking classified information, according to a 2021 New York Times story.",
#         "headline": 0,
#         "position": 12
#     },
#     {
#         "claim": "A top Democrat staffer was caught communicating with three reporters who published classified information he had access to, but the FBI didn't think it meant much.",
#         "headline": 0,
#         "position": 30
#     },
#     {
#         "claim": "The DOJ spied on as many Republicans as Democrats when investigating Democrat leaks, monitoring 21 Democrat staffers and 20 Republican staffers.",
#         "headline": 0,
#         "position": 54
#     }
# ]
# }
#
#
# Please consider the following recommendations:
#
# • If possible, use a noun as the subject in the claim (try to avoid pronouns),
# such as ”The Department of Justice's inspector general released a report on the DOJ's tracking of communications from media and congressional figures.”
# in the previous example.
# • Do not generate any novel word, be faithful to the provided input.
# • Do only include claims that can be considered core claims.
# • Do only include up to five core claims.
# • For each claim, indicate whether it was made in the headline (1) or not (0)
# • For each claim, indicate the position of the sentence, in which that claim was started, as indicated by the indices
# • Your response must be directly the JSON, do not add any other text, such as
# ”Here is the output:” and similar. Note that, each fact expressed in the source
# text must be present in the output.
# • Make sure that the JSON is properly formatted, especially with correct types of braces and brackets
# • For the total article, consider the total amount of sentences as indicted by the indices and add it in article_length
#
#
# Now do this task for this input
# INPUT:

# %%
import pandas as pd
article_file_path = f"{data_folder}/TRUE_articles_pre_processed.csv" 

df = pd.read_csv(article_file_path, sep=";", index_col=0)
df
# Out:
#                                                  URL  Response  Wayback URL  \
# 0  www.washingtontimes.com/news/2021/jul/19/arizo...       NaN          NaN
# 1  www.nbcnews.com/news/olympics/member-u-s-women...       NaN          NaN
# 2  www.dailywire.com/news/shock-nbc-poll-shows-am...       NaN          NaN
# 3  www.newsmax.com/us/ama-medical-doctor-langauge...       NaN          NaN
# 4  www.huffpost.com/entry/steve-buscemi-30-rock-m...       NaN          NaN
# 5  crooksandliars.com/2021/11/major-ivermectin-st...       NaN          NaN
# 6  www.newsmax.com/headline/terry-mcauliffe-glenn...       NaN          NaN
# 7  news.yahoo.com/qanon-supporters-gather-over-th...       NaN          NaN
# 8  bipartisanreport.com/2021/11/07/liz-cheney-app...       NaN          NaN
# 9  www.foxnews.com/politics/biden-approval-harris...       NaN          NaN
#
#                                                Title  \
# 0  Majority of Arizona Republicans believe electi...
# 1  Kara Eaker, U.S. women's gymnastics alternate,...
# 2  Shock NBC Poll Shows Americans Have ‘Lost Thei...
# 3  AMA Document: Doctors Should Use Language 'Ins...
# 4  Steve Buscemi Hands Out Candy Dressed As His O...
# 5  Ivermectin Study Retracted After Data Found To...
# 6        McAuliffe Concedes Virginia Governor's Race
# 7  QAnon supporters gather over theory that JFK J...
# 8  Liz Cheney Appears On ‘Fox Sunday’ To Hand Tru...
# 9  Nearly half of voters say Biden worse presiden...
#
#                                                 Body  \
# 0  \nMaricopa County ballots cast in the 2020 gen...
# 1  U.S. women's gymnastics alternates Kara Eaker ...
# 2  A whopping 71% of Americans believe the U.S. i...
# 3  he American Medical Association on Thursday re...
# 4  “Fargo” star Steve Buscemi handed out Hallowee...
# 5  Remember all those studies that purportedly sh...
# 6  Democrat Terry McAuliffe conceded defeat in th...
# 7  Some supporters of the QAnon conspiracy gather...
# 8  Rep. Liz Cheney (R-Wyo.) is continuing to face...
# 9  With exactly one year until the midterm electi...
#
#                                              id_body
# 0  {'headline': 'Majority of Arizona Republicans ...
# 1  {'headline': "Kara Eaker, U.S. women's gymnast...
# 2  {'headline': 'Shock NBC Poll Shows Americans H...
# 3  {'headline': "AMA Document: Doctors Should Use...
# 4  {'headline': 'Steve Buscemi Hands Out Candy Dr...
# 5  {'headline': 'Ivermectin Study Retracted After...
# 6  {'headline': "McAuliffe Concedes Virginia Gove...
# 7  {'headline': 'QAnon supporters gather over the...
# 8  {'headline': 'Liz Cheney Appears On ‘Fox Sunda...
# 9  {'headline': "Nearly half of voters say Biden ...

# %%
import time
last_call_time = time.time()

def get_throttled_prompt_response(value):
    global last_call_time
    elapsed_time = time.time() - last_call_time #dynamic buffer
    if elapsed_time < 8:
        time.sleep(8 - elapsed_time)
    try:
        last_call_time = time.time()
        return process_prompt(f"{prompt}{value}")
    except:
        return "ERROR: " + str(value)

# %%
df['claims'] = df['id_body'].apply(get_throttled_prompt_response) #run the last 700 entries again
print(df['claims'])
df.to_csv(f"{data_folder}/true_base_articles_with_claims.csv", sep=";") #for FM articles: this was run over two sessions (first one completing after 550mins, with the last ca. 700 entries being faulty (502 Error code))
# Out:
# 0    {\n    "article_title": "Majority of Arizona R...
# 1    {\n    "article_title": "Kara Eaker, U.S. wome...
# 2    {\n    "article_title": "Shock NBC Poll Shows ...
# 3    {\n    "article_title": "AMA Document: Doctors...
# 4    {\n    "article_title": "Steve Buscemi Hands O...
# 5    {\n    "article_title": "Ivermectin Study Retr...
# 6    {\n    "article_title": "McAuliffe Concedes Vi...
# 7    {\n    "article_title": "QAnon supporters gath...
# 8    {\n    "article_title": "Liz Cheney Appears On...
# 9    {\n    "article_title": "Nearly half of voters...
# Name: claims, dtype: object

# %% [markdown]
# When running over multiple sessions, reimport:

# %%
import pandas as pd
# df1 = pd.read_csv(f"{data_folder}/articles_with_claims.csv", sep=";", index_col=0)
# df2 = pd.read_csv(f"{data_folder}/articles_with_claims_part2.csv", sep=";", index_col=0)
df = pd.read_csv(f"{data_folder}/true_articles_with_claims.csv", sep=";", index_col=0)

# %%
# df = pd.concat([df1.head(1069), df2.tail(700)]) #joining the results from the two sessions
# df
# Out:
#                                                     url  \
# 1     https://abc13.com/us-shortages-gas-shortage-20...
# 2     https://abc7.com/covid-supply-chain-shortage-2...
# 3     https://abcnews.go.com/Politics/biden-replace-...
# 4     https://abcnews.go.com/Politics/whats-causing-...
# 5     https://abcnews.go.com/US/nature-based-man-mad...
# ...                                                 ...
# 1765  https://www.washingtonpost.com/politics/trump-...
# 1766  https://www.washingtonpost.com/politics/trump-...
# 1767  https://www.washingtonpost.com/politics/trump-...
# 1768  https://www.washingtonpost.com/politics/trump-...
# 1769  https://www.washingtonpost.com/politics/trump-...
#
#                                                   title  \
# 1     US shortages 2021: Gas, lumber prices soar; Ke...
# 2     Global supply chain problems now leading to em...
# 3     Biden to replace White House doctor with long-...
# 4     What’s causing America’s massive supply-chain ...
# 5     Nature-based or lab leak? Unraveling the debat...
# ...                                                 ...
# 1765  Trump clings to one marker as a sign of succes...
# 1766  Trump says ‘there was no reason’ for officer t...
# 1767  Trump Organization removes indicted top financ...
# 1768  Trump business and its longtime chief financia...
# 1769  Trump praises baseless QAnon conspiracy theory...
#
#                                                    body  \
# 1     WATCH LIVE NEW YORK -- Chicken, lumber, microc...
# 2     WATCH LIVE LOS ANGELES (KABC) -- At the beginn...
# 3     O'Connor will take on a role that faced scruti...
# 4     Untangling supply chain woes could take much l...
# 5     Accomplished scientists and public health offi...
# ...                                                 ...
# 1765  clockThis article was published more than 3 ye...
# 1766  clockThis article was published more than 3 ye...
# 1767  clockThis article was published more than 3 ye...
# 1768  clockThis article was published more than 3 ye...
# 1769  clockThis article was published more than 4 ye...
#
#                                                 id_body  \
# 1     {'headline': 'US shortages 2021: Gas, lumber p...
# 2     {'headline': 'Global supply chain problems now...
# 3     {'headline': 'Biden to replace White House doc...
# 4     {'headline': 'What’s causing America’s massive...
# 5     {'headline': 'Nature-based or lab leak? Unrave...
# ...                                                 ...
# 1765  {'headline': 'Trump clings to one marker as a ...
# 1766  {'headline': 'Trump says ‘there was no reason’...
# 1767  {'headline': 'Trump Organization removes indic...
# 1768  {'headline': 'Trump business and its longtime ...
# 1769  {'headline': 'Trump praises baseless QAnon con...
#
#                                                  claims
# 1     {\n"article_title": "US shortages 2021: Gas, l...
# 2     {\n"article_title": "Global supply chain probl...
# 3     {\n "article_title": "Biden to replace White H...
# 4     {\n"article_title": "What’s causing America’s ...
# 5     {\n"article_title": "Nature-based or lab leak?...
# ...                                                 ...
# 1765  {\n"article_title": "Trump clings to one marke...
# 1766  {\n"article_title": "Trump says ‘there was no ...
# 1767  {\n"article_title": "Trump Organization remove...
# 1768  ERROR: {'headline': 'Trump business and its lo...
# 1769  {\n "article_title": "Trump praises baseless Q...
#
# [1769 rows x 5 columns]

# %%
#df.to_csv(f"{data_folder}/articles_with_claims_merged.csv", sep=";")

# %%
def mark_errors(claim_output):
    if "ERROR:" in claim_output: #checking for model output errors (serverside)
        return True
    if "INVALID INPUT" in claim_output: #checking for input errors (that occured during sentencesplitting)
        return True
    else:
        return False

# %%
df['output_errors'] = df['claims'].apply(mark_errors)
df['pre_processing_errors'] = df['id_body'].apply(mark_errors) 
df['claims'].loc[df['output_errors'] == True] #FM: three iterations bringing the number of faulty outputs down from: 157 -> 1 -> 0; TRUE: 202 -> 1
# Out:
# 2757    ERROR: {'headline': 'Covid-19 news archive: Pf...
# Name: claims, dtype: object

# %%
len(df['claims'].loc[df['pre_processing_errors'] == True]) #16 faulty inputs (FM); 2 for TRUE sample
# Out:
# 2

# %%
#running until no output errors are left
df['claims'].loc[df['output_errors'] == True] = df['id_body'].loc[df['output_errors'] == True].apply(get_throttled_prompt_response)
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_8568\1295242433.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['claims'].loc[df['output_errors'] == True] = df['id_body'].loc[df['output_errors'] == True].apply(get_throttled_prompt_response)
# C:\Users\danie\AppData\Local\Temp\ipykernel_8568\1295242433.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['claims'].loc[df['output_errors'] == True] = df['id_body'].loc[df['output_errors'] == True].apply(get_throttled_prompt_response)

# %%
df.to_csv(f"{data_folder}/true_articles_with_claims.csv", sep=";") #articles_with_claims.csv

# %%
import json

def safe_json_loads(json_str):
    try:
        return json.loads(json_str)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {json_str}")
        print(e)
        return {}

# %%
import ast
df['id_body'] = df['id_body'].apply(ast.literal_eval) #convert the string literals back to a dict
df['Claims'] = df['Claims'].apply(ast.literal_eval)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\IPython\core\interactiveshell.py:3550 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[16], line 2
#     df['id_body'] = df['id_body'].apply(ast.literal_eval) #convert the string literals back to a dict
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\pandas\core\series.py:4917 in apply
#     return SeriesApply(
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\pandas\core\apply.py:1427 in apply
#     return self.apply_standard()
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\pandas\core\apply.py:1507 in apply_standard
#     mapped = obj._map_values(
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\pandas\core\base.py:921 in _map_values
#     return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
#   File c:\Users\danie\Desktop\Studium\Master's thesis\MA_Code\venv\lib\site-packages\pandas\core\algorithms.py:1743 in map_array
#     return lib.map_infer(values, mapper, convert=convert)
#
#   File lib.pyx:2972 in pandas._libs.lib.map_infer
#
#   File ~\AppData\Local\Programs\Python\Python39\lib\ast.py:62 in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File ~\AppData\Local\Programs\Python\Python39\lib\ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
#     INVALID INPUT
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
#export example

with open("newsmax_example.json", "w") as j:
    json.dump(df['Claims'][14], j)

# %%
# example = json.loads(df['Claims'][0])
# example_claims = example['claims']
# example_reference = df['ID_Body'][0]

def test_claim(claims, reference):
    for claim in claims:
        print(f"""
Claim: {claim['claim']}, 
    Position {claim['position']}, 
    Corresponding sentence: {reference[claim['position'] if claim['position'] != 0 else 'headline']}
        """)

for claim_data, reference in zip(df['Claims'], df['ID_Body']):
    claim_data =  r"" + claim_data
    claim_data = safe_json_loads(claim_data)
    claims = claim_data['claims']
    test_claim(claims, reference)

# test_claim(example_claims, example_reference)
# Out:
# Claim: Arizona state Sen. Wendy Rogers is demanding that the state’s electors — which went for President Joe Biden — be recalled, and a new election be conducted in the state.,
#     Position 1,
#     Corresponding sentence: C. Douglas Golden, The Western Journal By C. Douglas Golden, The Western Journal
# Published July 17, 2021 at 12:12pm
# Share on Facebook
# Tweet
# Mewe Share
# P Share
# Email
#
# In the wake of the Maricopa County audit of the 2020 election results, one GOP Arizona state senator is demanding that the state’s electors — which went for President Joe Biden — be recalled, and a new election be conducted in the state.
#
#
# Claim: The Maricopa County audit of the 2020 election results found that thousands of names were added to the voting rolls after election day, but are recorded as casting a ballot in the 2020 election.,
#     Position 11,
#     Corresponding sentence: According to Newsweek, Cyber Ninjas founder Doug Logan told the Arizona state Senate this week, “Thousands of names were added to the voting rolls after election day, but are recorded as casting a ballot in the 2020 election.”
#
#
# Claim: Up to 74,000 records for mail-in ballots were missing from Maricopa County, with the ballots received but no record of them being sent by elections officials.,
#     Position 12,
#     Corresponding sentence: Logan also told the Senate that up to 74,000 records for mail-in ballots were missing from Maricopa County — Arizona’s most populous jurisdiction, home to Phoenix.
#
#
# Claim: The lead auditor found support for the theory that Sharpies caused significant voter discrepancies in the Maricopa County tally, despite ballots being supposed to use a type of paper that doesn’t let markers like Sharpies bleed through the sheet.,
#     Position 17,
#     Corresponding sentence: — Kyle Becker (@kylenabecker) July 15, 2021
#
# The lead auditor also said his findings lent support to a theory that’s taken on the name “SharpieGate.”
#
#
# Claim: A digital security expert said the security on Maricopa County’s election systems was so poorly secured it could be hacked in under 10 minutes, and that an element of the election system was actually compromised or breached during the course of the November 2020 election.,
#     Position 20,
#     Corresponding sentence: Another auditor and digital security expert, Ben Cotton, said the security on Maricopa County’s election systems was so poorly secured it could be hacked in under 10 minutes.
#
#
# Claim: Dr. Robert Malone, a pioneer in the field of mRNA vaccines, shared a viral Twitter thread on Friday which lays out a disturbing trend; the most-vaccinated countries in the world are experiencing a surge in COVID-19 cases, while the least-vaccinated countries are not.,
#     Position 1,
#     Corresponding sentence: Tyler Durden's Photo
# by Tyler Durden
# Saturday, Jul 17, 2021 - 06:00 PM
#
# Dr. Robert Malone, a pioneer in the field of mRNA vaccines, shared a viral Twitter thread on Friday which lays out a disturbing trend; the most-vaccinated countries in the world are experiencing  a surge in COVID-19 cases, while the least-vaccinated countries are not.
#
#
# Claim: The most-vaccinated countries in the world are experiencing a surge in COVID-19 cases, while the least-vaccinated countries are not.,
#     Position 1,
#     Corresponding sentence: Tyler Durden's Photo
# by Tyler Durden
# Saturday, Jul 17, 2021 - 06:00 PM
#
# Dr. Robert Malone, a pioneer in the field of mRNA vaccines, shared a viral Twitter thread on Friday which lays out a disturbing trend; the most-vaccinated countries in the world are experiencing  a surge in COVID-19 cases, while the least-vaccinated countries are not.
#
#
# Claim: Cyprus, with a majority of its population vaccinated, has the highest case count in the world.,
#     Position 4,
#     Corresponding sentence: Highest case count in the world.
#
#
# Claim: Bhutan, which jabbed 64% of its population within one week, saw a surge in cases just a few days after the start of the rollout.,
#     Position 6,
#     Corresponding sentence: Just a few days after the start of the rollout, cases went up.
#
#
# Claim: The Emirates, with the highest vaccination rate in the world, experienced its second highest peak in cases since the pandemic began.,
#     Position 8,
#     Corresponding sentence: They just experienced their second highest peak since pandemic began.
#
#
# Claim: The nation's supply chain crisis is worsening, affecting the food supply and appearing to have been manufactured by the current regime to squeeze working-class Americans.,
#     Position 1,
#     Corresponding sentence: 11/01/2021 // JD Heyes // 17.8K Views
# Tags: bare shelves, Biden regime, food, food hoarding, hoarding, Inflation, regulations, schools, Shortages, starvation, supply chain
# As the nation's supply chain crisis worsens, three things are becoming apparent: One, there doesn't seem to be a solution around the corner; two, the nation's food supply is now being affected; and three, the crisis appears to have been manufactured by the current regime in order to squeeze working-class Americans, the largest faction of those who voted overwhelmingly for Donald Trump in 2020.
#
#
# Claim: Parts of the US are battling food shortages as worried Americans have emptied supermarket shelves amid the supply chain crisis threatening the nation’s economy and holiday shopping.,
#     Position 2,
#     Corresponding sentence: "Parts of the US are now battling food shortages as worried Americans have emptied supermarket shelves amid the supply chain crisis threatening the nation’s economy and holiday shopping," the New York Post noted this week in an incredibly eye-opening report that is as shocking as it is incredulous.
#
#
# Claim: The surge in demand comes as two of America’s major container ports in California face a massive pandemic-related backlog.,
#     Position 4,
#     Corresponding sentence: "The surge in demand comes as two of America’s major container ports in California face a massive pandemic-related backlog," The Post added.
#
#
# Claim: The food/supply chain crises are also beginning to negatively impact some public schools, with schools struggling with supply-chain issues with different items since school started.,
#     Position 19,
#     Corresponding sentence: The food/supply chain crises are also beginning to negatively impact some public schools.
#
#
# Claim: Republicans are calling out Biden himself over what he's done to make the supply chain problems worse, with Rep. Sam Graves saying the administration and Democrats are exacerbating or ignoring the underlying supply chain issues.,
#     Position 26,
#     Corresponding sentence: Republicans are onto the Biden regime, though; they are calling out Biden himself over what he's done to make the supply chain problems worse.
#
#
# Claim: The United States is losing respect on the world stage due to President Joe Biden's public blunders.,
#     Position 1,
#     Corresponding sentence: Grant Atkinson, The Western Journal By Grant Atkinson, The Western Journal
# Published November 1, 2021 at 11:42am
# Share on Facebook
# Tweet
# Mewe Share
# P Share
# Email
#
# As President Joe Biden continues to make public blunders nearly every time he speaks, the United States is losing respect on the world stage.
#
#
# Claim: Joe Biden said during a speech about infrastructure that a computer spoke to him.,
#     Position 6,
#     Corresponding sentence: First, Biden said during a speech about infrastructure that a computer spoke to him.
#
#
# Claim: Joe Biden slurred his words to the point they were indiscernible while speaking at a campaign event for Virginia gubernatorial candidate Terry McAuliffe.,
#     Position 7,
#     Corresponding sentence: Biden: “As one computer said, if you’re on the train, and they say Portal Bridge, you know you better make other plans…” pic.twitter.com/G4T1wX8Qdl
#
#     — The Post Millennial (@TPostMillennial) October 25, 2021
#
# Stop the censors, sign up to get today's top stories delivered right to your inbox
#
# Later in the week, Biden slurred his words to the point they were indiscernible while speaking at a campaign event for Virginia gubernatorial candidate Terry McAuliffe.
#
#
# Claim: Joe Biden planned to give about $450,000 per person to immigrant families who were separated at the border under former President Donald Trump.,
#     Position 11,
#     Corresponding sentence: When he’s not making a fool of himself misreading auto-cues, Biden is making utterly incomprehensible decisions that further weaken the U.S.”
#
# To support this second point, Panahi brought up a Thursday article from The Wall Street Journal in which the outlet reported Biden planned to give about $450,000 per person to immigrant families who were separated at the border under former President Donald Trump.
#
#
# Claim: The Biden administration has completely lost control of the southern border with more than 200,000 illegal immigrants encountered crossing a month.,
#     Position 12,
#     Corresponding sentence: “Of course, the Biden administration has completely lost control of the southern border with more than 200,000 illegal immigrants encountered crossing a month — and that’s the ones encountered,” Panahi said.
#
#
# Claim: A whistleblower involved in Pfizer's pivotal phase III Covid-19 vaccine trial has leaked evidence to a notable peer-reviewed medical publication that poor practices at the contract research company she worked for raise questions about data integrity and regulatory oversight.,
#     Position 1,
#     Corresponding sentence: by Tyler Durden
# Tuesday, Nov 02, 2021 - 02:25 PM
#
# A whistleblower involved in Pfizer's pivotal phase III Covid-19 vaccine trial has leaked evidence to a notable peer-reviewed medical publication that poor practices at the contract research company she worked for raise questions about data integrity and regulatory oversight.
#
#
# Claim: The whistleblower, Brook Jackson, a now-fired regional director at Ventavia Research Group, revealed to The BMJ that vaccine trials at several sites in Texas last year had major problems - including falsified data, broke fundamental rules, and were 'slow' to report adverse reactions.,
#     Position 2,
#     Corresponding sentence: Brook Jackson, a now-fired regional director at Ventavia Research Group, revealed to The BMJ that vaccine trials at several sites in Texas last year had major problems - including falsified data, broke fundamental rules, and were 'slow' to report adverse reactions.
#
#
# Claim: Ventavia executives later questioned Jackson for taking photos of poor laboratory management, patient safety concerns, and data integrity issues, and she was fired after notifying superiors of the issues she found.,
#     Position 3,
#     Corresponding sentence: When she notified superiors of the issues she found, they fired her.
#
#
# Claim: The FDA was notified of the issues, but did not inspect Ventavia following an employee complaint, and instead published a summary of its inspections of Pfizer's pivotal phase III trial, which did not include any of Ventavia's operations.,
#     Position 35,
#     Corresponding sentence: FDA notified
#
# Jackson sent a Sept. 25 email to the FDA in which she wrote that Ventavia had enrolled over 1,000 participants at three sites, out of the full trial's 44,000 participants across 153 sites which included various academic institutions and commercial companies.
#
#
# Claim: Two former Ventavia employees spoke with The BMJ anonymously, and confirmed 'broad aspects' of Jackson's account, stating that the company's work environment was 'helter skelter' and that they had never experienced such poor practices in their careers.,
#     Position 41,
#     Corresponding sentence: Other employees corroborate Jackson's complaints
#
# Two former Ventavia employees spoke with The BMJ anonymously, and confirmed 'broad aspects' of Jackson's account.
#
#
# Claim: Hillary Clinton and her campaign engaged in collusion with Russia while her presidential campaign was threatened by the FBI's probe of her mishandling of classified information.,
#     Position 0,
#     Corresponding sentence: Indictment shows it was Hillary who colluded with Russia
#
#
# Claim: The Clinton campaign and the Democratic National Committee financed the bogus Steele dossier, which became the premise for an Obama FBI investigation of the Trump campaign.,
#     Position 3,
#     Corresponding sentence: It's been known for some time that her campaign and the Democratic National Committee financed the bogus Steele dossier, which became the premise for an Obama FBI investigation of the Trump campaign that triggered a nearly two-year, $45 million special counsel probe that dominated
#
# Now, the arrest and indictment of the Russian citizen believed to be the dossier's primary "sub-source" has given the saga a new wrinkle.
#
#
# Claim: A Hillary Clinton lieutenant, Charles Dolan Jr., was the source of the infamous 'pee tape' claim in the Steele dossier, according to an indictment handed down by special counsel John Durham's office.,
#     Position 4,
#     Corresponding sentence: Some of the anti-Trump document's most sensational and now debunked claims, including the infamous "pee tape," came originally from a Hillary Clinton lieutenant, according to an indictment handed down Thursday by special counsel John Durham's office.
#
#
# Claim: Dolan, a communications consultant, has extensive ties to the Russian government, including relationships with 'senior Russian Federation leadership,' according to the indictment.,
#     Position 7,
#     Corresponding sentence: The Clinton operative Dolan, meanwhile, has extensive ties to the Russian government, including relationships with "senior Russian Federation leadership," the Danchenko indictment states.
#
#
# Claim: Special counsel John Durham's indictment of Igor Danchenko suggests that Durham 'has his sights set on the Clinton campaign,' according to former federal prosecutor Andrew C. McCarthy.,
#     Position 21,
#     Corresponding sentence: 'Sights set on the Clinton campaign'
# Former federal prosecutor Andrew C. McCarthy believes the indictment of Danchenko shows Durham "has his sights set on the Clinton campaign."
#
#
# Claim: Representative Paul Gosar accused Biden’s government of maintaining two secret lists that it uses to strip its enemies of their constitutional rights.,
#     Position 1,
#     Corresponding sentence: Monday, November 8, 2021 By Stillness in the Storm Leave a Comment
# Spread the love
# more
#
# (Joe Hoft) Representative Paul Gosar accused Biden’s government of maintaining two secret lists that it uses to strip its enemies of their constitutional rights.
#
#
# Claim: The two secret lists are the No Fly List and the NICS List, which the government uses to strip American citizens of their constitutional rights in secret, without charges, hearing, or due process.,
#     Position 4,
#     Corresponding sentence: Between the No Fly List and the NICS List, there are two secret lists the government uses to strip American citizens of their constitutional rights.
#
#
# Claim: Activist Laura Loomer was illegally red flagged by the FBI, banning her from owning or possessing a firearm, without ever notifying her when they placed her on the NICS database.,
#     Position 11,
#     Corresponding sentence: Congressman Gosar asked the FBI whether or not they were trying to entrap me when they illegally red flagged me, BANNING me from ever being able to own or possess a firearm, without ever notifying me when they placed me on the NICS database after I confronted former FBI Director James Comey.
#
#
# Claim: Congressman Paul Gosar is working with Laura Loomer on ANTI-RED FLAG legislation to prevent the FBI and DOJ from politically targeting Americans and stripping them of their Second Amendment Rights.,
#     Position 12,
#     Corresponding sentence: I’m pleased to announce I will be working with Congressman Gosar on ANTI-RED FLAG legislation so the FBI & DOJ can no longer politically target Americans & strip them of their Second Amendment Rights!
#
#
# Claim: Laura Loomer believes she is the test case for what Big Tech and the Biden regime want to make mainstream for all Conservative Americans, starting with banning them on social media, then from banks, and finally from owning guns.,
#     Position 16,
#     Corresponding sentence: First they ban you on social media.
#
#
# Claim: New York prosecutors criminally indicted Allen Weisselberg and the Trump Organization two weeks ago.,
#     Position 2,
#     Corresponding sentence: Donate now to help us fight back against Trump and the mainsteam media:
# Contribute $10
# Contribute $25
# Contribute $75
#
# When New York prosecutors criminally indicted Allen Weisselberg and the Trump Organization two weeks ago, it was clear that prosecutors were looking to flip Weisselberg against Trump.
#
#
# Claim: Jennifer Weisselberg, Allen Weisselberg's former daughter-in-law, has been a cooperating witness in the New York criminal case.,
#     Position 7,
#     Corresponding sentence: It’s long been established that Allen Weisselberg’s former daughter in law Jennifer Weisselberg has been a cooperating witness in the New York criminal case.
#
#
# Claim: Jennifer Weisselberg told New York prosecutors that Donald Trump personally guaranteed the unreported benefits that were used to allow Allen Weisselberg to avoid paying taxes on large chunks of his income.,
#     Position 9,
#     Corresponding sentence: Daily Beast is reporting that Jennifer Weisselberg told New York prosecutors that Donald Trump “personally guaranteed” the unreported benefits that were used to allow Allen Weisselberg to avoid paying taxes on large chunks of his income.
#
#
# Claim: Given that Allen Weisselberg was just indicted for knowingly having been on the receiving end of this fraudulent scheme, it stands to reason that prosecutors will also indict Donald Trump for knowingly having been on the paying end of this fraudulent scheme.,
#     Position 10,
#     Corresponding sentence: Given that Allen Weisselberg was just indicted for knowingly having been on the receiving end of this fraudulent scheme, it stands to reason that prosecutors will also indict Donald Trump for knowingly having been on the paying end of this fraudulent scheme.
#
#
# Claim: New York prosecutors will aim to indict Donald Trump for a lot more than just the Allen Weisselberg benefits scheme, and that they’ll seek more witnesses than just Jennifer Weisselberg.,
#     Position 12,
#     Corresponding sentence: Of course we expect New York prosecutors will aim to indict Donald Trump for a lot more than just the Allen Weisselberg benefits scheme, and that they’ll seek more witnesses than just Jennifer Weisselberg.
#
#
# Claim: Zero Covid nations are seeing explosions in Covid-19 cases across the board.,
#     Position 2,
#     Corresponding sentence: According to Zerohedge, Zero Covid nations are seeing explosions in Covid-19 cases across the board.
#
#
# Claim: Australia has been closed off from the vast majority of the world as part of its Zero Covid strategy.,
#     Position 5,
#     Corresponding sentence: The country has been closed off from the vast majority of the world.
#
#
# Claim: Countries such as Vietnam, South Korea, Singapore, China, Thailand and New Zealand have been using strict lockdowns, Covid surveillance systems and contact tracing measures as part of their Zero Covid strategy.,
#     Position 7,
#     Corresponding sentence: The countries such as Vietnam, South Korea, Singapore, China, Thailand and New Zealand have also been using strict lockdowns, Covid surveillance systems and contact tracing measures.
#
#
# Claim: These countries have experienced an explosive increase in COVID-19 cases without exception, or set their own Covid case records.,
#     Position 9,
#     Corresponding sentence: But recently, they have experienced an explosive increase in COVID-19 cases without exception, or set their own Covid case records.
#
#
# Claim: Zero Covid has been an unmitigated disaster, as Canberra’s elimination strategy has failed to permanently move cases to zero.,
#     Position 6,
#     Corresponding sentence: Zero Covid has been an unmitigated disaster, as Canberra’s elimination strategy has unsurprisingly failed to permanently move cases to zero.
#
#
# Claim: President Joe Biden had a town hall event in the Cincinnati area, which was virtually empty.,
#     Position 1,
#     Corresponding sentence: By
# C. Douglas Golden, The Western Journal
#
# July 25, 2021
#
# Truth
# Tweet
# Share
# Gettr
#
#
#
# Gab
# Telegram
#
# On Wednesday, President Joe Biden had a town hall event in the Cincinnati area.
#
#
# Claim: A former president, Donald Trump, appeared in Phoenix, Arizona, for an election integrity rally put on by the conservative group Turning Point Action, drawing a large crowd.,
#     Position 9,
#     Corresponding sentence: Meanwhile, on Saturday, a former president we're told is radioactive appeared in Phoenix, Arizona, for an election integrity rally put on by the conservative group Turning Point Action.
#
#
# Claim: Trump was speaking at the 'Rally for Election Integrity,' which was in support of both election integrity laws and the ongoing audit of the 2020 election in Maricopa County.,
#     Position 14,
#     Corresponding sentence: According to The Hill, Trump was speaking at the "Rally for Election Integrity," which was in support of both election integrity laws and the ongoing audit of the 2020 election in Maricopa County, where Pheonix is the county seat.
#
#
# Claim: Trump supporters lined up to get into the event, held at the 5,000-seat Arizona Federal Theatre, with many being turned away after the venue reached capacity.,
#     Position 17,
#     Corresponding sentence: While the atmosphere was lively inside, it began hours before as Trump supporters lined up to get into the event, held at the 5,000-seat Arizona Federal Theatre:
#
#     Look at that huge line in Arizona of patriots waiting for President Trump's rally!
#
#
# Claim: The obvious takeaway is the difference in the enthusiasm gap between President Biden and former President Trump, with Trump drawing bigger crowds after leaving office than Joe Biden has since he took office.,
#     Position 28,
#     Corresponding sentence: https://t.co/VlT7z8drtO pic.twitter.com/8FeqKunPmy
#
#     — Newsmax (@newsmax) July 24, 2021
#
# The obvious takeaway is the difference in the enthusiasm gap between President Biden and former President Trump.
#
#
# Claim: The Senate held hearings on whether or not the National Institutes of Health provided funding for gain-of-function research.,
#     Position 2,
#     Corresponding sentence: Today, the Senate held hearings on whether or not the National Institutes of Health provided funding for a kind of research that right-wingers like Senator Rand Paul (R-TX) want us to believe helped cause the coronavirus outbreak.
#
#
# Claim: Dr. Anthony Fauci denied allegations that the NIH backed gain-of-function research that led to the pandemic during a previous Senate testimony.,
#     Position 4,
#     Corresponding sentence: Conservatives have rallied around the idea that the NIH backed such research and that it led to the pandemic despite Fauci denying such allegations during a previous Senate testimony.
#
#
# Claim: Senator Rand Paul asked Dr. Fauci if he wished to retract his statement of May 11th where he claimed the NIH never funded gain-of-function research in Wuhan.,
#     Position 7,
#     Corresponding sentence: “Knowing it’s a crime to lie to Congress, do you wish to retract your statement of May 11th where you claimed the NIH never funded gain-of-function research in Wuhan?”
#
#
# Claim: Dr. Fauci stated that the paper referred to by Senator Paul was judged by qualified staff as not being gain-of-function research.,
#     Position 9,
#     Corresponding sentence: “Senator Paul I have never lied before the Congress and I do not retract that statement,” said Fauci without hesitation. “
#
#
# Claim: Dr. Fauci told Senator Paul that he does not know what he is talking about and that his implication that the NIH is responsible for COVID-19 and the ensuing deaths does not make sense to anyone who actually understands the science.,
#     Position 26,
#     Corresponding sentence: He explained Paul’s implication that the NIH is responsible for COVID-19 and the ensuing deaths simply doesn’t make sense to anyone who actually understands the science.
#
#
# Claim: Illinois employers are hurting from a lack of workers while the state unemployment rate remains high.,
#     Position 1,
#     Corresponding sentence: Tyler Durden's Photo
# by Tyler Durden
# Sunday, Jul 25, 2021 - 06:30 PM
#
# Authored by Noah Sheer via IllinoisPolicy.org,
#
# Illinois employers are hurting from a lack of workers while the state unemployment rate remains high.
#
#
# Claim: The average Illinoisan earns $55,770 a year at work, but if they stayed home with their kids and collected unemployment, it would be $51,627.,
#     Position 4,
#     Corresponding sentence: The average Illinoisan earns $55,770 a year at work.
#
#
# Claim: The Chicagoland Chamber of Commerce calculated that an unemployed worker receives $35 an hour, making it difficult for employers to compete with the enhanced UI benefits, tax credits, and stimulus payments.,
#     Position 7,
#     Corresponding sentence: Crunch the numbers another way and add federal stimulus, and the Chicagoland Chamber of Commerce calculated an unemployed worker receives $35 an hour.
#
#
# Claim: Illinois’ 7.2% unemployment rate exceeds the national average of 5.9%, and government policies are not helping reduce it.,
#     Position 11,
#     Corresponding sentence: Illinois’ 7.2% unemployment rate exceeds the national average of 5.9%.
#
#
# Claim: The state of Illinois will not require unemployment recipients to search for a job, unlike some other states, and will continue to pay the extra $300 in federal pandemic unemployment relief through September 6.,
#     Position 18,
#     Corresponding sentence: “I don’t want to pull the rug out from under people that have certainly legitimate reasons for remaining on unemployment,” Pritzker said when asked about the reform.
#
#
# Claim: Speaker Nancy Pelosi is ultimately responsible for the breakdown of security at the Capitol that happened on January 6.,
#     Position 9,
#     Corresponding sentence: "Speaker Pelosi is ultimately responsible for the break down of security at the Capitol that happened on January 6." -
#
#
# Claim: Pelosi objected to Rep. Jim Banks being picked for the select committee because she was afraid of 'tough questions'.,
#     Position 3,
#     Corresponding sentence: Throughout the segment, Rep. Banks emphasized that Pelosi objected to such picks because she was afraid of "tough questions."
#
#
# Claim: Pelosi has predetermined a narrative about Donald Trump and Republicans, and is only interested in answers that fit that narrative.,
#     Position 4,
#     Corresponding sentence: She's also "only interested in a narrative," and answers which fit that narrative, Banks offered, and that "that's all that this comes down to," which includes how "she has already predetermined a narrative about Donald Trump, about Republicans."
#
#
# Claim: The head of the U.S. Capitol Police Union told Rep. Jim Banks that the police were not prepared, trained, or equipped for the January 6 riot.,
#     Position 8,
#     Corresponding sentence: They weren't prepared for it, they weren't trained for it, and, maybe most important of all, they weren't equipped for it," he said, noting the police "lacked equipment" when it came to "something like what at that point should have been expected would occur."
#
#
# Claim: Pelosi has more control and authority over the leadership of the Capitol Police than anyone else in the United States Capitol.,
#     Position 10,
#     Corresponding sentence: @RepJimBanks #FoxNewsSunday
#     — FoxNewsSunday (@FoxNewsSunday) July 25, 2021
#
# Banks explained how it all comes back to Nancy Pelosi because as the speaker, she "has more control and authority and responsibly over the leadership of the Capitol Police than anyone else in the United States Capitol."
#
#
# Claim: Michelle Witthoeft, Babbitt’s mother, says Speaker of the House Nancy Pelosi is responsible for her daughter’s death.,
#     Position 2,
#     Corresponding sentence: Michelle Witthoeft, Babbitt’s mother, says Speaker of the House Nancy Pelosi is responsible for her daughter’s death.
#
#
# Claim: The Capitol Police should be held accountable like every other police department in the country.,
#     Position 13,
#     Corresponding sentence: “The Capitol Police should be held accountable like every other police department in the country.”
#
#
# Claim: Former President Donald Trump asked who shot Ashli Babbitt.,
#     Position 15,
#     Corresponding sentence: In a July 1 statement, former President Donald Trump asked only the following question: “Who shot Ashli Babbitt?”
#
#
# Claim: Babbitt’s family announced that they were suing the Capitol Police for “at least $10 million” in damages.,
#     Position 21,
#     Corresponding sentence: Back in April, Babbitt’s family announced that they were suing the Capitol Police for “at least $10 million” in damages.
#
#
# Claim: The Department of Justice released a statement saying that prosecutors would have to prove that the officer responsible used “constitutionally unreasonable” force against Babbitt.,
#     Position 23,
#     Corresponding sentence: On April 14, after conducting an investigation, the Department of Justice released a statement on the matter.
#
#
# Claim: The Department of Justice's inspector general released a report on the DOJ's tracking of communications from media and congressional figures.,
#     Position 1,
#     Corresponding sentence: (Brandon Bell/Getty Images)
#
#
# By Eric Mack    |   Monday, 26 July 2021 10:09 PM EDT
#
# Comment|
# Print|
#     A   A
#
# With House Speaker Nancy Pelosi, D-Calif., moving forward with the Jan. 6 Select Committee with only Democrats and two anti-Trump Republicans not approved by House Minority Leader Kevin McCarthy, R-Calif., former President Donald Trump called out Pelosi's conflict of interest.
#
#
# Claim: House Speaker Nancy Pelosi is moving forward with the Jan. 6 Select Committee with only Democrats and two anti-Trump Republicans not approved by House Minority Leader Kevin McCarthy.,
#     Position 1,
#     Corresponding sentence: (Brandon Bell/Getty Images)
#
#
# By Eric Mack    |   Monday, 26 July 2021 10:09 PM EDT
#
# Comment|
# Print|
#     A   A
#
# With House Speaker Nancy Pelosi, D-Calif., moving forward with the Jan. 6 Select Committee with only Democrats and two anti-Trump Republicans not approved by House Minority Leader Kevin McCarthy, R-Calif., former President Donald Trump called out Pelosi's conflict of interest.
#
#
# Claim: Former President Donald Trump called out Pelosi's conflict of interest, asking if she will investigate herself and those on Capitol Hill who didn't want additional protection, including more police and National Guard.,
#     Position 4,
#     Corresponding sentence: "Will Nancy investigate herself and those on Capitol Hill who didn't want additional protection, including more police and National Guard, therefore being unprepared despite the large crowd of people that everyone knew was coming?"
#
#
# Claim: Trump also asked if Pelosi's committee will study the massive voter fraud that took place during the 2020 presidential election, particularly in swing states.,
#     Position 7,
#     Corresponding sentence: "Will Nancy and her Committee study the massive voter fraud that took place during the 2020 presidential election, particularly in swing states, that was the reason hundreds of thousands of people came pouring into Washington and, therefore, must be a big factor in the final committee report?"
#
#
# Claim: Trump questioned whether Pelosi will release the thousands of hours of tapes to show the extent to which ANTIFA and Black Lives Matter played a role in the Jan. 6 protest and the storming of the Capitol.,
#     Position 11,
#     Corresponding sentence: "Will Nancy release the thousands of hours of tapes so we can see the extent to which ANTIFA and Black Lives Matter played a role, while also revealing 'who killed Ashli Babbitt?'"
#
#
# Claim: Matt Gaetz and Marjorie Taylor Greene were run out of their own protest rally.,
#     Position 1,
#     Corresponding sentence: Bocha Blue | 2:32 pm EDT July 27, 2021
#
# Palmer Report » Community
# 5043
# SHARES
# Facebook Share
# X Share
# Email this article
# Print Article
# Whatsapp
# Pinterest
# Palmer Report will never stop fighting for you.
#
#
# Claim: The goal of the insurrection supporters was to demand answers about the Capitol terrorist prisoners.,
#     Position 6,
#     Corresponding sentence: The goal of the insurrection supporters was to demand answers about the Capitol terrorist prisoners.
#
#
# Claim: Protesters showed up and drowned out the insurrection party members with loud voices, whistles, and catcalls.,
#     Position 14,
#     Corresponding sentence: Protesters showed up.
#
#
# Claim: The crowd labeled the evil terrorist supporters 'traitors'.,
#     Position 19,
#     Corresponding sentence: The crowd labeled the evil terrorist supporters “traitors.”
#
#
# Claim: The vile GOP members couldn’t get a word in edgewise and the protest ended with the insurrectionists being chased away.,
#     Position 24,
#     Corresponding sentence: The vile GOP members couldn’t get a word in edgewise.
#
#
# Claim: The NIH Director Francis Collins was grilled by CNN's Pamela Brown over the NIH's funding of New York-based nonprofit, EcoHealth alliance, which performed gain-of-function research in Wuhan, China.,
#     Position 2,
#     Corresponding sentence: In a blistering Sunday night interview, CNN's Pamela Brown (credit where it's due) absolutely grilled Collins over the NIH's funding of New York-based nonprofit, EcoHealth alliance, which performed textbook Gain of Function research - genetically engineering bat coronaviruses so they can infect humans.
#
#
# Claim: The NIH admitted that EcoHealth violated the terms of a grant by failing to report their achievement, sending both Fauci and Collins into full damage control.,
#     Position 3,
#     Corresponding sentence: Last week the NIH admitted that EcoHealth violated the terms of a grant by failing to report their achievement (which EcoHealth denies), sending both Fauci and Collins into full damage control over the weekend.
#
#
# Claim: CNN's Brown pressed Collins to explain how NIH could not know for two years that its own contractor EcoHealth had done research making bat coronaviruses more infectious to humans.,
#     Position 9,
#     Corresponding sentence: Jumping right into it (video at the bottom):
#
#     Brown repeatedly presses Collins to explain how NIH could not know FOR TWO YEARS that its own contractor @EcoHealthNYC had done research making bat coronaviruses more infectious to humans, and Collins uses every rhetoric trick to dissemble and distract... I'll explain...
#     — Josh Rogin (@joshrogin) October 26, 2021
#
# Continued via threadreaderapp (emphasis ours):
#
# Brown repeatedly presses Collins to explain how NIH could not know FOR TWO YEARS that its own contractor @EcoHealthNYC had done research making bat coronaviruses more infectious to humans, and Collins uses every rhetoric trick to dissemble and distract... I'll explain...
#
# Fauci claimed no "Gain of Function research was being funded in Wuhan.
#
#
# Claim: Collins acknowledged EcoHealth violated its contract but claimed they did not do the kind of gain-of-function research that requires special, high-level oversight.,
#     Position 13,
#     Corresponding sentence: Collins acknowledges EcoHealth violated its contract but then says, weirdly:
#
# "Yes, they did some things they should have told us about, but they did not do the kind of Gain of Function research that requires special, high level oversight."
#
#
# Claim: Brown questioned Collins on why the American people should trust the NIH after last week's revelation, and Collins failed to provide a clear answer.,
#     Position 26,
#     Corresponding sentence: OF COURSE IT IS...
#
# This time, Collins actually blames Congress for preventing NIH from interacting with sub=grantees (the Wuhan lab), completely sidestepping why NIH didn't ask EcoHealth (the primary grantee) for its Wuhan report FOR TWO YEARS, while a pandemic raged coming from Wuhan...
#
# Brown presses Collins to on the core issue:“Why should Americans trust you and the NIH on the issue of covid origins, when you didn’t even know about the programs it was funding with taxpayer dollars in China?"
